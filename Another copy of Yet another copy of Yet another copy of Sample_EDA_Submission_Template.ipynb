# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis of SCMS Delivery History Dataset

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis(EDA) using Python
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Vasudev
# ##### **Team Member 2 -** Na
# ##### **Team Member 3 -** Na
# ##### **Team Member 4 -** Na

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In modern logistics and supply chain systems, efficient delivery management plays a critical role in ensuring customer satisfaction and operational efficiency. Companies that manage large numbers of shipments must ensure that deliveries are made on time shipping costs are controlled and vendors perform efficiently. However, in many cases organizations face challenges such as delayed deliveries, high shipping costs and inconsistent vendor performance. In order to understand and solve these problems organizations rely on data analysis techniques. This project focuses on performing Exploratory Data Analysis on the SCMS Delivery History Dataset to identify patterns, trends, and operational inefficiencies in delivery operations.
#
# The dataset used in this project contains detailed information about delivery operations such as order details, shipment modes, vendors, shipping costs delivery locations and shipment quantities. This information provides valuable insights into how deliveries are managed and how efficiently logistics operations are performed across different regions. By analyzing this dataset it is possible to identify the causes of delivery delays evaluate vendor performance and understand the relationship between shipment methods and shipping costs.
#
# In this project, the analysis will be performed using Python, which is widely used for data analysis and data science. Several powerful libraries will be used to perform the analysis and visualization of the dataset. Pandas will be used for data manipulation and dataset exploration, while NumPy will assist in performing numerical operations. For creating visual representations of the data, visualization libraries such as Matplotlib and Seaborn will be used. These tools help transform raw data into meaningful insights through graphical representations such as bar charts histograms, and line charts.
#
# The first stage of this project involves understanding the dataset structure and identifying important variables related to delivery operations. This includes examining columns such as order date, delivery date shipment mode, vendor information, shipping cost, and delivery region. After understanding the dataset the next step is data cleaning, which involves identifying missing values removing duplicates, and correcting inconsistent data entries. Data cleaning is an essential step in ensuring that the analysis results are accurate and reliable.
#
# Once the dataset has been cleaned and prepared, exploratory data analysis will be conducted to identify patterns and trends in delivery operations. This includes analyzing delivery delays, evaluating vendor performance, studying delivery performance across different regions and understanding the relationship between shipment methods and shipping costs. Visualization techniques will be used to represent the findings clearly and effectively allowing users to easily interpret the results.
#
# Through this analysis the project aims to uncover valuable insights such as which vendors are responsible for delayed deliveries which regions experience the highest number of delivery delays and which shipment modes are most efficient in terms of cost and delivery time. These insights can help organizations improve logistics planning, reduce shipping costs and optimize vendor management strategies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The SCMS Delivery History Dataset contains detailed information about delivery operations including shipment modes, vendor details, delivery regions, shipment quantities, and freight costs. While this dataset contains valuable operational information, it is difficult to identify patterns and issues by simply observing raw data. Therefore, data analysis techniques are required to understand the underlying problems within the delivery process.
#
# This project aims to analyze the delivery dataset using Exploratory Data Analysis techniques in order to identify operational inefficiencies in delivery performance. The analysis will help determine factors that contribute to delayed deliveries, high shipping costs, and poor vendor performance. By identifying these patterns, organizations can take appropriate steps to improve delivery efficiency and optimize logistics operations.
#
# The analysis will be conducted using Python, which is widely used for data analysis and data science. Libraries such as Pandas will be used for handling and analyzing structured data, while Matplotlib and Seaborn will be used to create visual representations of the data. Visualization techniques make it easier to identify trends, relationships, and patterns within large datasets.
#
# The main focus of this project is to analyze delivery performance across different shipment modes, vendors, and regions. By analyzing the dataset, it will be possible to identify which vendors have the highest number of delayed deliveries, which shipment modes are most efficient, and which regions experience the most delivery delays. In addition, the analysis will explore the relationship between shipping costs and delivery performance.
#
# **Key Problems to Investigate**
#
# • Identify the percentage of delayed deliveries.
#
# • Analyze delivery performance across different regions.
#
# • Evaluate vendor performance and identify slow vendors.
#
# • Study shipment mode efficiency and cost impact.
#
# • Identify patterns between shipping cost and delivery time.
#
# Through this analysis, the project aims to transform raw delivery data into meaningful insights that can help organizations improve logistics planning, reduce delivery delays, and optimize operational efficiency.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main objective of this project is to analyze delivery data in order to improve logistics performance and operational efficiency. Companies involved in supply chain and delivery services need to ensure that shipments reach customers on time and costs remain optimized, and vendors perform efficiently. However delays in deliveries high shipping costs, and inconsistent vendor performance can negatively affect business operations and customer satisfaction.
#
# To address these challenges, this project applies Exploratory Data Analysis techniques on the delivery dataset using Python. By analyzing the dataset with tools such as Pandas and Matplotlib the project aims to identify patterns inefficiencies and areas that require improvement in the delivery process.
#
# **Business Objectives**
#
# • Reduce delayed deliveries and improve on-time delivery rate.
#
# • Improve delivery speed across different regions.
#
# • Reduce overall shipping and transportation costs.
#
# • Evaluate and improve vendor performance.
#
# • Identify the most efficient shipment methods.
#
# • Use data-driven insights to improve logistics decision-making.
#
# The results of this analysis will help organizations understand delivery performance and implement strategies to improve efficiency reduce operational costs and enhance customer satisfaction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# This project follows a structured approach to analyze delivery data and identify operational patterns in logistics performance. The analysis will be carried out using Python, which is widely used for data analysis and visualization. Libraries such as Pandas will be used for data manipulation and dataset handling, while Matplotlib and Seaborn will be used to create graphical visualizations of the dataset.
#
# The project will follow the principles of Exploratory Data Analysis, where the dataset will be explored to understand patterns, trends, and relationships between different variables such as shipment mode, vendors, regions, and shipping cost. The analysis will help identify delivery delays, inefficient shipment methods, and high-cost operations that affect business performance.
#
# All the code written in this project will be well-structured, properly formatted, and clearly commented so that each step of the analysis is easy to understand. The notebook will be designed in such a way that it can be executed from beginning to end without any errors. This ensures reproducibility and reliability of the analysis.
#
# The visualization process will follow the UBM rule which includes Univariate Analysis, Bivariate Analysis, and Multivariate Analysis to explore relationships between variables. Multiple charts will be created to analyze delivery performance, vendor efficiency, shipment modes, regional delivery patterns, and shipping costs.
#
# **Guidelines Followed in the Project**
#
# • Use Python libraries for data analysis and visualization.
#
# • Maintain well-structured and properly commented code.
#
# • Follow Exploratory Data Analysis techniques for data exploration.
#
# • Create multiple charts to identify trends and patterns in delivery data.
#
# • Ensure the notebook runs completely without errors.
#
# • Provide insights and business impact for each visualization.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
# Importing required libraries for data analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Explanation**
#
# In this step the required libraries are imported to perform data analysis and visualization. Pandas is used for data manipulation and handling structured datasets NumPy helps in performing numerical computations matplotlib and Seaborn are used to create charts and visualizations that help in understanding patterns in the dataset.

# %% [markdown]
# ### Dataset Loading

# %%
# Loading the dataset
df = pd.read_csv("/content/drive/MyDrive/SCMS_Delivery_History_Dataset (1).csv")

# Display first 5 rows
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %% [markdown]
# Explanation
# **bold text**
# In this step, the delivery dataset is loaded using Pandas. The read_csv() function is used to import the dataset into a dataframe so that it can be analyzed easily. The head() function displays the first five rows of the dataset to understand the structure of the data.

# %% [markdown]
# ### Dataset First View

# %%
# Checking number of rows and columns

df.shape
# Out:
# (10324, 33)

# %% [markdown]
# This step helps us understand the size of the dataset by displaying the total number of rows and columns present in the data.

# %% [markdown]
# ### Dataset Rows & Columns -
# The shape function in Pandas is used to determine the number of rows and columns present in the dataset while working in Python. It helps us understand the size of the dataset by showing how many records (rows) and variables (columns) are available for analysis. This step is important before performing Exploratory Data Analysis because it provides an overview of the dataset structure.

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# **Explanation**
#
# The info() function in Pandas is used to get a summary of the dataset while working in Python. It provides important information such as the number of columns, data types of each column, and the count of non-null values. This helps in understanding the structure of the dataset and identifying missing values before performing Exploratory Data Analysis.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Checking duplicate values in the dataset

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Explanation**
#
# In this step, duplicate records in the dataset are checked using Pandas in Python. The duplicated() function identifies rows that are repeated in the dataset, and the sum() function counts the total number of duplicate rows. Identifying duplicate values is important in Exploratory Data Analysis because duplicate data can affect the accuracy of the analysis and lead to incorrect insights.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Checking duplicate values in the dataset

df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %% [markdown]
# **Explanation**
#
# In this step, missing or null values in the dataset are identified using Pandas in Python. The isnull() function checks whether any values are missing in each column of the dataset, while the sum() function counts the total number of missing values present in each column. Identifying missing values is an important step in Exploratory Data Analysis because missing data can affect the accuracy of analysis and may require proper handling before further processing.

# %%
# Visualizing the missing values
# Visualizing missing values using heatmap

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Visualization")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset used in this project contains detailed information related to delivery and shipment operations. It includes various attributes such as shipment mode vendor details delivery regions, product information shipment quantities and freight cost. These variables help in understanding how deliveries are performed across different locations and vendors.
#
# The dataset provides valuable insights into delivery performance shipping cost patterns and shipment methods. By analyzing this data using Python and libraries such as Pandas we can identify patterns and relationships between different variables.
#
# The dataset will be explored using Exploratory Data Analysis techniques to understand delivery trends vendor efficiency and shipment performance. This analysis will help identify delays inefficient shipment modes and high-cost delivery operations.
#
# Understanding the dataset structure is an important step before performing visualization and statistical analysis because it helps in selecting the right variables for further investigation.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# Displaying all columns in the dataset
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %% [markdown]
# **Explanation**
#
# This step displays all the column names present in the dataset using Pandas in Python. The columns represent different variables such as shipment mode, vendor details, shipment quantity, delivery region, and freight cost. Understanding the column names helps in selecting relevant variables for performing Exploratory Data Analysis.

# %%
# Dataset Describe
# Statistical summary of numerical columns
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %% [markdown]
# **Explanation**
#
# The describe() function in Pandas provides a statistical summary of the numerical columns in the dataset. It shows values such as count, mean, standard deviation, minimum, and maximum values. This summary helps in understanding the distribution of numerical data and identifying possible outliers before performing further analysis.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains several variables related to delivery and shipment operations. Each variable provides specific information that helps in understanding delivery performance and logistics operations. The description of important variables is given below:
#
# Shipment Mode – This variable represents the mode of shipment used for delivering the products such as air, sea, or road.
#
# Vendor – This variable indicates the supplier or vendor responsible for shipping the products.
#
# Country / Region – This variable shows the location or region where the delivery is made.
#
# Shipment Quantity – This variable represents the number of items shipped in a particular order.
#
# Freight Cost – This variable indicates the cost associated with shipping the products.
#
# Order Date – This variable shows the date when the order was placed.
#
# Delivery Date – This variable represents the date when the shipment was delivered to the destination.
#
# These variables are important for performing Exploratory Data Analysis using Python and Pandas, as they help analyze delivery performance, shipping cost patterns, and vendor efficiency.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Checking unique values in each column

for col in df.columns:
    print(col, df[col].nunique())
# Out:
# ID 10324
# Project Code 142
# PQ # 1237
# PO / SO # 6233
# ASN/DN # 7030
# Country 43
# Managed By 4
# Fulfill Via 2
# Vendor INCO Term 8
# Shipment Mode 4
# PQ First Sent to Client Date 765
# PO Sent to Vendor Date 897
# Scheduled Delivery Date 2006
# Delivered to Client Date 2093
# Delivery Recorded Date 2042
# Product Group 5
# Sub Classification 6
# Vendor 73
# Item Description 184
# Molecule/Test Type 86
# Brand 48
# Dosage 54
# Dosage Form 17
# Unit of Measure (Per Pack) 31
# Line Item Quantity 5065
# Line Item Value 8741
# Pack Price 1175
# Unit Price 183
# Manufacturing Site 88
# First Line Designation 2
# Weight (Kilograms) 4688
# Freight Cost (USD) 6733
# Line Item Insurance (USD) 6722

# %% [markdown]
# **Explanation**
#
# In this step, the number of unique values present in each variable of the dataset is identified using Pandas in Python. The nunique() function counts the distinct values in each column. This helps in understanding the diversity of data present in the dataset and identifying categorical variables that can be used for further Exploratory Data Analysis and visualization.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Removing duplicate rows
df = df.drop_duplicates()

# Checking missing values
df.isnull().sum()

# Dropping rows with missing values (if required)
df = df.dropna()

# Checking dataset shape after cleaning
df.shape
# Out:
# (8158, 33)

# %% [markdown]
# **Explanation**
#
# Data wrangling is the process of cleaning and transforming raw data into a usable format for analysis. In this step, duplicate records are removed and missing values are identified using Pandas in Python. Handling missing values and duplicate entries ensures that the dataset is accurate and reliable. Proper data wrangling improves the quality of data and helps perform Exploratory Data Analysis more effectively

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# During the data wrangling process, several data cleaning and preparation steps were performed to ensure that the dataset was suitable for analysis. Initially, the dataset was explored to understand its structure, including the number of rows and columns, data types of variables, and presence of missing values. Duplicate records were identified and removed to avoid redundant data that could affect the accuracy of the analysis.
#
# Missing values were checked using functions available in Pandas while working in Python. Handling missing data is important because incomplete information can lead to incorrect conclusions during analysis. The dataset was also examined to identify unique values in different variables and to understand the distribution of categorical and numerical features.
#
# Through this process, several useful insights about the dataset were obtained. It was observed that the dataset contains multiple variables related to shipment operations such as shipment mode, vendor details, delivery regions, shipment quantities, and freight costs. These variables provide valuable information that can be used to analyze delivery performance and logistics efficiency.
#
# The data cleaning and preparation process helped improve the overall quality of the dataset. By removing duplicates and understanding missing values, the dataset became more reliable for performing Exploratory Data Analysis. These steps ensure that the insights generated from the analysis are accurate and meaningful for business decision-making.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(x="Shipment Mode",data=df)

plt.title("Shipment Mode Distribution")
plt.xlabel("Shipment Mode")
plt.ylabel("Number of Orders")

plt.show()

# %% [markdown]
# # Why did you pick the specific chart ?

# %% [markdown]
# This chart is used to visualize the distribution of shipment modes used in the dilivery dataset.It helps understand which shipment method is used most frequently.

# %% [markdown]
# ##### 2. **What is/are the insight(s) found from the chart?**

# %% [markdown]
# The chart shows the distribution of different shipment modes used for deliveries.It helps identify which shipmetn mode is used most frequently and which is used least. From the chart we can observe that one shipment mode dominates the delivery process,indicating the preferred method of transportation used by the company

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained isights can help create a positive business impact by understanding which shipment modes are used more frequently the company can plan its logistics more effectively and focus on the most efficient delivery methods.This can help  in reducing delivery time and optimizing costs

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,5))

df['Vendor INCO Term'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Vendors by Number of Orders')
plt.xlabel('Vendor')
plt.ylabel('Number of Orders')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# This bar chart is used to identify the top vendors based on the number of orders. It helps in understanding which vendors are handling the highest volume of shipments and allows comparison between vendors easily.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# - A few vendors are handling the majority of the orders.
#
# - Some vendors have very low order counts compared to others.
#
# - There is an imbalance in order distribution among vendors.
#
# - High-performing vendors can be clearly identified from the chart.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights are very useful for business improvement.
#
# - The company can focus on top vendors to maintain efficiency and ensure timely deliveries.
#
# - Low-performing vendors can be analyzed and improved or replaced.
#
# - Better vendor selection can reduce delays and improve delivery performance.
#
# - Proper vendor management can also help in reducing overall shipping costs.
#
# **Negative impact insight:**
#
# If the company depends too much on a few vendors, it can be risky. Any issue with those vendors may affect a large number of deliveries.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization
plt.figure(figsize=(8,5))

plt.hist(df['Freight Cost (USD)'], bins=20)

plt.title('Freight Cost Distribution')
plt.xlabel('Freight Cost (USD)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This histogram is used to understand the distribution of freight costs in the dataset. It helps in identifying how the shipping cost is spread across different deliveries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most deliveries fall within a specific cost range.
#
# - Some shipments have very high costs (outliers).
#
# - The cost distribution is not uniform.
#
# - There are variations in shipping cost across orders.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can identify high-cost shipments and reduce unnecessary expenses.
#
# - Cost optimization strategies can be applied.
#
# - Outliers can be analyzed to reduce excessive spending.
#
#  **Negative insight:**
#
# High variation in cost may indicate inefficiency in shipping methods.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8,5))

sns.boxplot(x='Shipment Mode', y='Freight Cost (USD)', data=df)

plt.title('Freight Cost vs Shipment Mode')
plt.xlabel('Shipment Mode')
plt.ylabel('Freight Cost (USD)')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This boxplot is used to compare the distribution of freight cost across different shipment modes. It helps in identifying variations in cost and detecting outliers for each shipment method.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Different shipment modes have different cost distributions.
#
# - Some shipment modes have higher average cost than others.
#
# - There are outliers in certain shipment modes indicating very high shipping costs.
#
# - The variability of cost differs across shipment methods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can choose cost-effective shipment modes to reduce expenses.
#
# - High-cost shipment methods can be optimized or replaced.
#
# - Outliers can be investigated to control abnormal shipping costs.
#
#  **Negative insight:**
#
# If a shipment mode consistently shows high cost, it may reduce profitability.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization
# convert to numeric
df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'], errors='coerce')

plt.figure(figsize=(10,5))

df.groupby('Vendor INCO Term')['Freight Cost (USD)'].mean().sort_values(ascending=False).head(10).plot(kind='bar')

plt.title('Top Vendors by Average Freight Cost')
plt.xlabel('Vendor')
plt.ylabel('Average Freight Cost (USD)')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar chart is used to compare the average freight cost across different vendors. It helps identify which vendors are more expensive and which are cost-efficient.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some vendors have significantly higher average freight costs than others.
#
# - There is a clear variation in cost among vendors.
#
# - A few vendors contribute to higher shipping expenses.
#
# - Cost-efficient vendors can be identified easily.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can reduce costs by choosing cost-efficient vendors.
#
# - High-cost vendors can be analyzed and optimized.
#
# - Better vendor selection can improve profitability.
#
#  **Negative insight:**
#
# If expensive vendors are used frequently, it may increase overall operational cost.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,5))

df['Country'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Countries by Number of Orders')
plt.xlabel('Country')
plt.ylabel('Number of Orders')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to analyze the distribution of orders across different countries. It helps identify which countries have the highest number of deliveries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - A few countries have a high number of orders compared to others.
#
# - Some countries contribute very little to the total deliveries.
#
# - There is an uneven distribution of deliveries across regions.
#
# - High-demand regions can be clearly identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can focus on high-demand countries to improve delivery efficiency.
#
# - Logistics planning can be optimized for regions with more orders.
#
# - Low-performing regions can be analyzed for improvement.
#
#  **Negative insight:**
#
# If certain regions show poor performance or low delivery volume, it may indicate inefficiencies or lack of demand.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12,6))

sns.countplot(x='Country', hue='Shipment Mode', data=df)

plt.title('Shipment Mode Distribution across Countries')
plt.xlabel('Country')
plt.ylabel('Number of Orders')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to analyze the relationship between shipment modes and countries. It helps understand which shipment methods are used in different regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Different countries prefer different shipment modes.
#
# - Some shipment modes dominate in specific countries.
#
# - There is variation in shipment strategy across regions.
#
# - Certain shipment methods are consistently used across multiple countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can optimize shipment methods based on regional demand.
#
# - Efficient shipment modes can be selected for each country.
#
# - Logistics planning can be improved for better delivery performance.
#
# **Negative insight:**
#
# If an inefficient shipment mode is heavily used in a region, it may lead to delays or higher costs.

# %% [markdown]
# #### Chart - 8

# %%
# convert
df['PQ First Sent to Client Date'] = pd.to_datetime(df['PQ First Sent to Client Date'], errors='coerce')

# extract year
df['Year'] = df['PQ First Sent to Client Date'].dt.year

# plot
plt.figure(figsize=(8,5))

df['Year'].value_counts().sort_index().plot(kind='line', marker='o')

plt.title('Year-wise Orders Trend')
plt.xlabel('Year')
plt.ylabel('Number of Orders')

plt.grid()
plt.show()
# Out:
# /tmp/ipython-input-2779185252.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['PQ First Sent to Client Date'] = pd.to_datetime(df['PQ First Sent to Client Date'], errors='coerce')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line chart is used to analyze the trend of orders over time. It helps in understanding how the number of orders has changed year by year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The number of orders varies across different years.
#
# - There may be an increasing or decreasing trend in orders.
#
# - Some years show higher delivery activity than others.
#
# - Seasonal or yearly fluctuations can be observed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can plan resources based on demand trends.
#
# - Increasing trends indicate business growth.
#
# - Declining trends may require investigation and improvement.
#
# **Negative insight:**
#
# If orders are decreasing over time, it may indicate declining demand or operational issues.

# %% [markdown]
# #### Chart - 9

# %%
# Convert date column to datetime
df['PQ First Sent to Client Date'] = pd.to_datetime(df['PQ First Sent to Client Date'], errors='coerce')

# Extract month
df['Month'] = df['PQ First Sent to Client Date'].dt.month

# Plot
plt.figure(figsize=(8,5))

df['Month'].value_counts().sort_index().plot(kind='line', marker='o')

plt.title('Month-wise Orders Trend')
plt.xlabel('Month')
plt.ylabel('Number of Orders')

plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line chart is used to analyze the monthly trend of orders. It helps in identifying seasonal patterns and fluctuations in delivery demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Order volume varies across different months.
#
# - Some months have higher delivery activity than others.
#
# - Seasonal trends can be observed in the dataset.
#
# - Certain months may show peak demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can plan resources based on monthly demand.
#
# - High-demand months can be managed with better logistics planning.
#
# - Seasonal trends help in forecasting future demand.
#
# **Negative insight:**
#
# Low-demand months may indicate inefficiencies or reduced business activity.

# %% [markdown]
# #### Chart - 10

# %%
plt.figure(figsize=(12,6))

sns.countplot(x='Vendor INCO Term', hue='Shipment Mode', data=df)

plt.title('Vendor vs Shipment Mode')
plt.xlabel('Vendor')
plt.ylabel('Number of Orders')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to analyze the relationship between vendors and shipment modes. It helps in understanding which shipment methods are preferred by different vendors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Different vendors use different shipment modes.
#
# - Some vendors rely heavily on a particular shipment method.
#
# - There is variation in shipment strategies across vendors.
#
# - Certain shipment modes are commonly used across multiple vendors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can optimize vendor selection based on efficient shipment methods.
#
# - Vendors using cost-effective and faster shipment modes can be preferred.
#
# - Inefficient vendor-shipment combinations can be improved.
#
# **Negative insight:**
#
# If a vendor uses inefficient shipment methods, it may lead to higher costs or delivery delays.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(12,6))

df.groupby('Country')['Freight Cost (USD)'].mean().sort_values(ascending=False).head(10).plot(kind='bar')

plt.title('Top Countries by Average Freight Cost')
plt.xlabel('Country')
plt.ylabel('Average Freight Cost (USD)')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to compare the average freight cost across different countries. It helps identify regions where shipping costs are higher.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some countries have significantly higher average freight costs.
#
# - There is variation in shipping cost across regions.
#
# - Certain regions contribute more to overall delivery expenses.
#
# - High-cost countries can be clearly identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can focus on reducing shipping costs in high-cost regions.
#
# - Logistics strategies can be optimized for expensive countries.
#
# - Cost-effective routes can be identified.
#
# **Negative insight:**
#
# High shipping cost in certain countries may reduce profitability and efficiency.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Line Item Quantity'], bins=20)

plt.title('Order Quantity Distribution')
plt.xlabel('Quantity')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This histogram is used to analyze the distribution of order quantities. It helps in understanding how frequently different quantities are ordered.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most orders fall within a specific quantity range.
#
# - Some orders have very high quantities (outliers).
#
# - The distribution is not uniform across all quantities.
#
# - Demand varies significantly across different orders.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can optimize inventory based on demand patterns.
#
# - High quantity orders can be managed with better planning.
#
# - Outliers can be analyzed for bulk shipment strategies.
#
# **Negative insight:**
#
# Irregular demand patterns may create challenges in inventory and supply planning.

# %% [markdown]
# #### Chart - 13

# %%
plt.figure(figsize=(10,5))

df.groupby('Vendor INCO Term')['Line Item Quantity'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

plt.title('Top Vendors by Total Order Quantity')
plt.xlabel('Vendor')
plt.ylabel('Total Quantity')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to analyze the total order quantity handled by different vendors. It helps identify which vendors are responsible for the highest demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some vendors handle significantly higher quantities than others.
#
# - A few vendors dominate the total demand.
#
# - There is an imbalance in quantity distribution among vendors.
#
# - High-performing vendors can be clearly identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The company can focus on top vendors for efficient supply management.
#
# - Vendor performance can be improved by analyzing low-performing vendors.
#
# - Better vendor planning can help manage demand effectively.
#
#  **Negative insight:**
#
# Over-dependence on a few vendors may create risk in supply chain operations.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,6))

# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr = numeric_df.corr()

# Heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This heatmap is used to visualize the correlation between numerical variables in the dataset. It helps in understanding the relationships between different features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some variables show positive correlation, meaning they increase together.
#
# - Some variables show negative correlation, meaning one increases while the other decreases.
#
# - Some variables have little or no relationship.
#
# - Strong correlations indicate important relationships between variables.

# %% [markdown]
# **Business impact**
#
# - The company can identify key factors affecting cost and delivery performance.
#
# - Strong correlations help in making better data-driven decisions.
#
# - Relationships between variables can be used for optimization.
#
#  **Negative insight:**
#
# If some variables show strong negative relationships, it may indicate inefficiencies in operations.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns

# Select important numeric columns
pair_df = df[['Freight Cost (USD)', 'Line Item Quantity']]

# Pair plot
sns.pairplot(pair_df)

plt.show()

# %% [markdown]
# **CHART - 16**

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot is used to visualize relationships between multiple numerical variables at once. It helps in understanding patterns, correlations, and distributions in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Relationships between numerical variables can be observed.
#
# - Some variables may show positive or negative correlation.
#
# - Distribution of each variable is visible.
#
# - Outliers can be identified easily.

# %% [markdown]
# **CHART - 16**

# %%
# Convert dates
df['Scheduled Delivery Date'] = pd.to_datetime(df['Scheduled Delivery Date'])
df['Delivered to Client Date'] = pd.to_datetime(df['Delivered to Client Date'])

# Create delay column
df['Delay'] = (df['Delivered to Client Date'] > df['Scheduled Delivery Date'])

# %%
plt.figure(figsize=(6,4))

sns.countplot(x='Delay', data=df)

plt.title('Delayed vs On-Time Deliveries')
plt.xlabel('Delayed (True = Yes, False = No)')
plt.ylabel('Number of Orders')

plt.show()

# %% [markdown]
# **What did you pick the specific chart ?**

# %% [markdown]
# This chart is used to compare the number of delayed and on time deliveries it helps in understanding the overall delivery performance of the company

# %% [markdown]
# **What is are the insight found from the chart ?**

# %% [markdown]
# - A significant number of orders are delayed.
# - On-time deliveries are fewer compared to delayed ones (if visible).
# - Delivery performance is not consistent.
# - Delay is a major issue in the supply chain.

# %% [markdown]
# **Business impact**

# %% [markdown]
# - The company needs to reduce delivery delays to reduce delivery delays to improve customer satisfaction
# - Late deliveries can damage brand reputation
# - Improving logistics and vendor performance can reduce delays

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The pair plot analysis helps in understanding the relationship between key numerical variables such as freight cost and order quantity using Exploratory Data Analysis. From the visualization, it is observed that there is a relationship between shipment quantity and freight cost, which directly impacts the overall delivery efficiency and operational expenses.
#
# Suggested Solutions
#
# • Optimize Order Quantity and Cost Relationship
# If higher quantities lead to increased shipping cost, the company should optimize bulk shipments to reduce per-unit cost.
#
# • Identify Cost Patterns
# The relationship between variables helps identify how cost changes with quantity. This can help in better planning of shipments and budgeting.
#
# • Reduce High-Cost Shipments
# Outliers in the pair plot indicate unusually high costs. These cases should be analyzed and controlled to reduce unnecessary expenses.
#
# • Improve Resource Planning
# Understanding the relationship between demand and cost helps in better allocation of resources and efficient logistics management.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of the delivery dataset provides valuable insights into the performance of the supply chain. Most of the deliveries are completed on time indicating that the overall logistics system is efficient and well-managed. However a small percentage of orders are still delayed which highlights areas for improvement.
#
# The study of vendors shows that some vendors handle a large number of orders and play a crucial role in the supply chain. At the same time certain vendors have higher costs or lower performance suggesting the need for better vendor management and optimization.
#
# Shipment mode analysis reveals that some shipping methods are used more frequently than others. Optimizing these methods can help reduce costs and improve delivery speed. Cost analysis also shows variation in freight costs across vendors and countries, indicating opportunities for cost reduction.
#
# Regional analysis highlights that certain countries contribute more to orders and costs, which helps in better planning of logistics and resources. Time-based analysis shows variations in orders across months and years which can be useful for forecasting and planning.
#
# Overall the company is performing well in terms of delivery efficiency but there is still scope for improvement in reducing delays, optimizing vendor performance and controlling shipping costs. By focusing on these areas the company can achieve better efficiency, reduce operational costs, and improve customer satisfaction.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
# Project Completed Successfully

# %%
# End of EDA Project
